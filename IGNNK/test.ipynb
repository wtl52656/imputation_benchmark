# %%
from basic_structure import IGNNK
import torch

# %%
model = IGNNK(12, 64, 1)

# %%
A_q = torch.rand((307, 307))
A_h = A_q.permute(0, 1)

# %%
x = torch.zeros((4, 307, 12))

# %%
model(x, A_q, A_h)
# Out:
# tensor([[[1193.2548,    0.0000, 1666.5261,  ...,    0.0000,  897.4160,
#              0.0000],
#          [1261.5952,    0.0000, 1761.9551,  ...,    0.0000,  948.8451,
#              0.0000],
#          [1251.9677,    0.0000, 1748.5149,  ...,    0.0000,  941.5903,
#              0.0000],
#          ...,
#          [1230.0387,    0.0000, 1717.8972,  ...,    0.0000,  925.0855,
#              0.0000],
#          [1235.4347,    0.0000, 1725.4225,  ...,    0.0000,  929.1644,
#              0.0000],
#          [1247.4541,    0.0000, 1742.1853,  ...,    0.0000,  938.2443,
#              0.0000]],
#
#         [[1193.2545,    0.0000, 1666.5271,  ...,    0.0000,  897.4155,
#              0.0000],
#          [1261.5952,    0.0000, 1761.9551,  ...,    0.0000,  948.8451,
#              0.0000],
#          [1251.9677,    0.0000, 1748.5149,  ...,    0.0000,  941.5903,
#              0.0000],
#          ...,
#          [1230.0386,    0.0000, 1717.8972,  ...,    0.0000,  925.0854,
# ...
